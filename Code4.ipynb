# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import pandas as pd
import time

options = Options()
options.add_argument("--disable-blink-features=AutomationControlled")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
# options.add_argument("--headless=new")
options.add_argument("--window-size=1920,1080")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

jobs_list = []
driver = webdriver.Chrome(options=options)
driver.get('https://www.naukrigulf.com/data-engineer-jobs')

driver.maximize_window()
time.sleep(3)

for page in range(3):   
        jobs = driver.find_elements(By.CLASS_NAME,'designation-title')
        time.sleep(2)
        companies = driver.find_elements(By.CLASS_NAME,'info-org')
        Locations = driver.find_elements(By.CLASS_NAME,'info-loc')
        Experiences = driver.find_elements(By.CLASS_NAME,'info-exp')
        Description = driver.find_elements(By.CLASS_NAME,'description')
        #time.sleep(3)
        for job,company,location,exp,desc in zip (jobs,companies,Locations,Experiences,Description):
                job_title = job.text
                job_company = company.text
                job_location = location.text
                job_exp = exp.text
                job_desc = desc.text
                jobs_list.append(
                        {
                        'Title' : job_title,
                        'Company' : job_company,
                        'Location' : job_location,
                        'Experience' : job_exp,
                        'Description' :job_desc
                        
                        }
                )

        driver.find_element(By.CSS_SELECTOR,'.ico.bwd').click()
        time.sleep(2)
        
driver.close()

# %%
df = pd.DataFrame(jobs_list)
df
# Out:
#                          Title                                      Company  \
# 0         DATA ENGINEER – (DX)                            STAR SERVICES LLC
# 1                Data Engineer                      Trigyn Technologies ltd
# 2   Applied AI & Data Engineer                  Morgan's Holding Global LLC
# 3        FinTech Data Engineer                 Acesoft Labs (India) Pvt Ltd
# 4                Data Engineer                 Acesoft Labs (India) Pvt Ltd
# ..                         ...                                          ...
# 85       Data Engineer DBT SQL                       Devoteam International
# 86        Senior Data Engineer  Mirai Arabian International Company Limited
# 87               Data Engineer                           Fixed Misr (FEDIS)
# 88  Data Engineer (Mid/Senior)                                       Yassir
# 89               Data Engineer                      Client of Tandem Search
#
# ...

# %%
df.to_csv('naukrigulf.csv')
